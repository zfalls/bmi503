# %% [markdown]
# # Lab Exercise 01
# ---
# Data types, data structures, and basic functions

# %% [markdown]
# ## Data types
#
# - Integer
# - String
# - Float
# - NoneType

# %%
# This is an integer
x = 4
print(x)
print(type(x))

# %%
# This is a float
x = 4.0
print(x)
print(type(x))

# %%
# This is a string
x = "4"
print(x)
print(type(x))

# %%
# This is a NoneType
x = None
print(x)
print(type(x))

# %% [markdown]
# ## Type casting
# Reset an assigned variable as a new data type
#
# - `int()`
# - `float()`
# - `str()`
#
# Use `type()` to determine variable data type.

# %%
# Set x as int
x = 4
print(type(x))

# Cast x as a float
x = float(x)
print(type(x))

# %% [markdown]
# ### Practice
# Cast x as an int

# %%
# x is a str
x = "4"
# Cast x as an int
x =

# %% [markdown]
# ## Strings and string manipulation
#
# Strings are like arrays in python. You can select any character in the string by selecting its index.
#
# Python is a zero index language, i.e., the first position in an array is 0.

# %%
# Set x as a string
x = "Hello World"
print(x)

# %%
# Print the H in Hello World
print(x[0:5])

# %% [markdown]
# Determine the length of a string (or any array) using `len()`

# %%
# Print the length of x, i.e., Hello World
print(len(x))

# %% [markdown]
# Concatenate strings using `+` operator

# %%
x = "Hello"
y = "World"
print(x + " " + y)

# %% [markdown]
# Use the `format()` method to incorporate non string variables into a string.

# %%
x = "Hello World"
y = 1000
print("{0} World {0}".format(x[-2],y))

# %% [markdown]
# ### Practice
#
# What is wrong with the cell below? Fix it.

# %%
x = "The Ultimate Answer to Life, The Universe and Everything is..."
y = 42
print(x + y)

# %% [markdown]
# ## Data structures
#
# Enables storage of multiple values in a single variable
#
# - Lists
# - Dictionaries
# - Tuples
# - Sets

# %% [markdown]
# ## Lists
#
# Create a list using square brackets `[ ]`
#
# Can contain heteroegenous data types, i.e. `[1, 'a', 4.0]`
#
# Ordered, changeable, and allows duplicates

# %%
l = [1,2,3,3]
print(l)

# %% [markdown]
# Get length of list using `len()`

# %%
print(len(l))

# %% [markdown]
# Lists are ordered...
#
# Select list items by using the square brackets on the list variable (same as we did for strings).

# %%
print(l[0])
print(l[2])

# %% [markdown]
# Select multiple items from a list using square brackets with a colon to define the range. The last index defined is NOT included.

# %%
# Print the first two indicies of the list, i.e., index 0 and  index 1.
# Index 2 is not included
print(l[0:2])

# %% [markdown]
# Lists are changeable...
#
# Reassign items in a list by chossing the index and resetting it.

# %%
# Original list
print(l)
# Rassign the Index 3 (fourth item) to 4
l[3] = 4
print(l)

# %% [markdown]
# Reorder lists using the `sort()` method.

# %%
l = [3,1,2,4]
print(l)
l.sort()
print(l)

# %% [markdown]
# `sort()` is by default ascending. You can change this to descending by using the argument `reverse=True`.

# %%
l.sort(reverse=True)
print(l)

# %% [markdown]
# Add item to list two ways:
#
# 1. `append()` to the end of the list
# 2. `insert()` at a specific index in the list

# %%
l = [1,2,3]
print(l)
# append() takes an value/variable as an argument
l.append(4)
print(l)

# %%
l = [1,2,4]
print(l)
# insert() takes an index and a value/variable as arguments
l.insert(2, 3)
print(l)

# %% [markdown]
# Remove items from a list using three methods:
#
# 1. `remove()` to delete an item based on the value
# 2. `pop()` to delete an item based on index
# 3. `del` to delete an item by index or the whole list

# %%
l = [1,2,3,4]
print(l)
# remove() takes a value/variable as an argument
y = l.remove(4)
print(l)
print(y)

# %%
l = [1,2,3,4]
print(l)
# pop() takes an index as an argument
y = l.pop(3)
print(l)
print(y)

# %%
l = [1,2,3,4]
print(l)
# del can be used on a list item or the whole list
del l[3]
print(l)

# %% [markdown]
# ## Dictionaries
#
# Create a dictionary using curly brackets and define keys and values - `{"key": value}`
#
# Ordered, changeable, and does not allow duplicates

# %%
d = {'name': 'Michael', 'color': 'blue', 'number': 3}
print(d)

# %% [markdown]
# Access items in dictionary by using the key as an index.

# %%
print(d['color'])

# %% [markdown]
# All view all keys in a dict using `keys()` method or all values using the `values()` method.

# %%
print(d.keys())

# %%
print(d.values())

# %% [markdown]
# Change the value of an item using the key index.

# %%
d = {'name': 'Michael', 'color': 'blue', 'number': 3}
print(d)
d['name']='Bob'
print(d)

# %% [markdown]
# Add a new item (key and value) to a dict by using the key index.

# %%
d = {'name': 'Michael', 'color': 'blue', 'number': 3}
print(d)
d['role']='student'
print(d)

# %% [markdown]
# Remove items using `pop()` or `del`.

# %%
d = {'name': 'Michael', 'color': 'blue', 'number': 3}
print(d)
d.pop('number')
print(d)

# %%
d = {'name': 'Michael', 'color': 'blue', 'number': 3}
print(d)
del d['number']
print(d)

# %% [markdown]
# ## Tuples
#
# Create a tuple using round brackets `(value1, value2)`
#
# Ordered, unchangeable, and allows duplicates

# %%
t = (1,2,3)
print(t)

# %% [markdown]
# Access items in tuple using index.

# %%
print(t[0])
print(t[0:2])

# %% [markdown]
# In order to change a tuple one must change a tuple to a list, modify it, then recast it as a tuple.

# %%
t = (1,2,3)
print(t)
# We can't append to a tuple -- unchangeable
t.append(4)

# %%
t = (1,2,3)
print(t)
t = list(t)
t.append(4)
t = tuple(t)
print(t)

# %% [markdown]
# ## Sets
#
# Create a set using curly brackets `{value1, value2}`
#
# Unordered, unchangeable, and does not allow duplicates

# %%
s = {'a','b','c'}
print(s)

# %%
# No duplicate items
s = {'a','b','c','c'}
print(s)

# %% [markdown]
# Sets are not indexed, so we can't access items in the set.
#
# Sets are unchangeable, but we can add or remove items using `add()` or `remove()`.

# %%
s = {'a','b','c'}
print(s)
s.add('d')
print(s)

# %%
s = {'a','b','c'}
print(s)
s.remove('a')
print(s)

# %% [markdown]
# ## Arithmetic operators
#
# Very similar to typical math operations. Order of operations follows typical math rules, and you can use parentheses to control it.
#
# - `+` add
# - `-` subtract
# - `*` multiply
# - `/` divide
# - `%` mod (remainder)
# - `//` divide (floor)
# - `**` exponentiation (power of)

# %%
# +, -, *, and / work the way you'd expect
x = 10
y = 3
print(x + y)
print(x - y)
print(x * y)
print(x / y)

# %% [markdown]
# The mod operator (`%`) returns the *remainder* after division, not the quotient.

# %%
x = 10
y = 3
# 10 divided by 3 is 3, with 1 left over
print(x % y)

# %% [markdown]
# A common use for `%` is checking whether a number is even or odd: any number is even if `number % 2` equals `0`.

# %%
x = 8
print(x % 2 == 0)

x = 7
print(x % 2 == 0)

# %% [markdown]
# Floor division (`//`) divides and then rounds *down* to the nearest whole number, instead of returning a decimal.

# %%
x = 10
y = 3
print(x / y)   # regular division
print(x // y)  # floor division

# %% [markdown]
# Exponentiation (`**`) raises a number to a power. Note that this is `**`, not `^` like in some other languages.

# %%
x = 2
y = 3
# 2 to the power of 3
print(x ** y)

# %% [markdown]
# ### Practice
# Using the variables below, do the following:
#
# 1. Set `remainder` to the remainder of `a` divided by `b`, using the mod operator.
# 2. Set `whole` to the result of `a` divided by `b`, rounded down, using floor division.
# 3. Set `power` to `b` raised to the power of `3`, using the exponentiation operator.

# %%
# I have defined the variables for you.
# RUN THIS CELL FIRST.
# DO NOT CHANGE THIS CELL.
a = 17
b = 4

# %%
remainder = 
whole = 
power = 

print(remainder)
print(whole)
print(power)

# %% [markdown]
# ## Conditionals and loops

# %% [markdown]
# ## If...else
# `if` statements rely on conditional statements to determine whether a block of code will be run.
#
# After any statement where we will be defining a block of code (code that will only be run if the condition is met) we must end the condition or statement with a colon, `:`.

# %%
# Set variable
a = 1
# Check if variable is less than a value
# If True, print variable
if a < 3:
    print(a)

# %% [markdown]
# ## Indentation
# Notice in the above cell we indent the `print` statement. We do this to let pythong know that we want that code to run only if it passes the conditional.

# %%
# This code is correct
if 1 < 3:
    print(1)

# %%
# This code is NOT correct
# Can you fix it?
if 1 < 3:
print(1)

# %%
# This code is NOT correct
# Can you fix it?
if 1 < 3:
    print(1)
    print("<")
        print(3)

# %% [markdown]
# So far we've only run a block of code when a condition is `True`. We can also define a block of code to run when the condition is `False`, using the `else` statement.
#
# Note that `else` never gets its own condition — it simply catches whatever the `if` (and any `elif`) above it did not.

# %%
a = 5
# Check if a is less than 3
if a < 3:
    print("a is less than 3")
else:
    print("a is NOT less than 3")

# %% [markdown]
# The `else` block only runs when the `if` condition is `False`. Let's change `a` and run the same logic again.

# %%
a = 1
# Check if a is less than 3
if a < 3:
    print("a is less than 3")
else:
    print("a is NOT less than 3")

# %% [markdown]
# Now let's add `elif` to the code.

# %%
a = 3
# Check if a is less than 3
if a < 3:
    print("a is less than 3")
elif a > 3:
    print("a is greater than 3")
else:
    print("a is equal to 3")

# %% [markdown]
# ### Practice
# Using the variable below, print `"Positive"` if `n` is greater than `0`. Otherwise, print `"Not positive"`. You *MUST* use an `if...else` statement.

# %%
# I have defined the variable for you.
# RUN THIS CELL FIRST.
# DO NOT CHANGE THIS CELL.
n = -4

# %%
# Write your code here to answer the question


#

# %% [markdown]
# ## Multiple statements
# What if we want to check two different conditions?
#
# This can be accomplished multiple ways depending on how we want to do it.
#
# We can use the logical operators `and` and/or `or` to check multiple conditions in a single statment.

# %%
a = 1
# Check if a is less than 3 AND a is less than 2
if a < 3 and a < 2:
    print("a is less than 3")
    print("a is less than 2")

# %% [markdown]
# Or we may want to check if the second condition is `True` after we have confirmed the first condition is `True`. We can do this using a nested statement and block of code.

# %%
a = 1
# First, check if a is less than 3
if a < 3:
    print("a is less than 3")
    # Second, check if a is less than 2
    if a < 2:
        print("a is less than 2")

# %% [markdown]
# Notice in the above the indentation for the nested statement. If the first condition was not `True` then the `print` and second conditional will not be assessed.

# %%
a = 1
# First, check if a is less than 1
if a < 1:
    print("a is less than 1")
    # Second, check if a is less than 2
    if a < 2:
        print("a is less than 2")

# %% [markdown]
# Even though `a` is less than 2 in the above cell, it was never checked because it was a nested conditional.

# %% [markdown]
# Another part of if...else statements is the `elif` keyword, which gives us the ability to check a separate condition if the previous conditions are not met.

# %%
a = 1
# Check if a is less than 1
if a < 1:
    print("a is less than 1")
# Check if a is less than 2
elif a < 2:
    print("a is less than 2")

# %% [markdown]
# Notice how the `elif` condition was met, so that block of code was run. whereas the first condition was not and its corresponding block of code was not run.
#
# If we change this up and both conditions are met, then what will happen?

# %%
a = 1
# Check if a is less than 3
if a < 3:
    print("a is less than 3")
# Check if a is less than 2
elif a < 2:
    print("a is less than 2")

# %% [markdown]
# Another important logical operator is `not`. This allows the user to set a negative condition to be the required condition., i.e., a `False` would result in a `True`/met condition.

# %%
a = 1
# a < 0 is a False statement
print(a < 0)

# %%
a = 1
# But, we can check if a is NOT less than 0
if not a < 0:
    print("a is NOT less than 0")

# %% [markdown]
# ## While loops
#
# We can run the same block of code until a specific condition is met.

# %%
i = 0
# Print i until i is not less than 3
while i < 3:
    print(i)
    i+=1

# %% [markdown]
# What happens if you create a while loop where the condition is never met?

# %%
i = 0
# Print i until i is not less than 3
while i < 3:
    print(i)
    i-=1

# %% [markdown]
# You can end a loop early using the `break` statement

# %%
i = 0
# Print i until i is not less than 3
while i < 3:
    # End the loop if i equals 1
    if i==1:
        break
    print(i)
    i+=1

# %% [markdown]
# In the above cell, you can see we used a nested `if` statement within a while loop.

# %% [markdown]
# You can skip an iteration of a loop using the `continue` statement

# %%
i = 0
# Print i until i is not less than 3
while i < 3:
    # Continue to the next iteration if i equals 1
    if i==1:
        i+=1
        continue
    print(i)
    i+=1

# %% [markdown]
# You can run a block of code after a while loop has terminated using the `else` statement

# %%
i = 0
# Print i until i is not less than 3
while i < 3:
    print(i)
    i+=1
# Once the loop ends...
else:
    print("i is equal to 3")

# %% [markdown]
# ## For loops
#
# We can iterate over a sequence, such as a list, string, dictionary, etc.
#
# To do this, we will use a `for` loop.

# %%
l = ['blue','yellow','red']
# Iterate over the list
for x in l:
    print(x)

# %% [markdown]
# We can also iterate over strings

# %%
s = "Hello World!"
# Iterate over the string
for x in s:
    print(x)

# %% [markdown]
# The `break` and `continue` statements can also be used within for loops.

# %%
l = ['blue','yellow','red']
# Iterate over the list
for x in l:
    # End the loop if x equals 'yellow'
    if x == 'yellow':
        break
    print(x)

# %%
l = ['blue','yellow','red']
# Iterate over the list
for x in l:
    # End the loop if x equals 'yellow'
    if x == 'yellow':
        continue
    print(x)

# %% [markdown]
# Just like `while` loops, you can run a block of code after a `for` loop finishes using the `else` statement.

# %%
l = ['blue','yellow','red']
# Iterate over the list
for x in l:
    print(x)
# Once the loop ends...
else:
    print("Done.")

# %% [markdown]
# **Important:** the `else` block only runs if the loop completes normally. If the loop is stopped early with `break`, the `else` block is skipped — even though the loop technically "ended."

# %%
l = ['blue','yellow','red']
# Iterate over the list
for x in l:
    # End the loop if x equals 'yellow'
    if x == 'yellow':
        break
    print(x)
else:
    print("Done.")

# %% [markdown]
# Notice "Done." was **not** printed in the cell above, because the loop exited early via `break`. This is different from an `if...else` statement, where the `else` block runs any time the `if` condition is `False` — a loop's `else` is about *how the loop ended*, not a condition being unmet.

# %% [markdown]
# ### Practice
# Print each item in `colors` using a `for` loop. After the loop completes, print `"All done!"` using an `else` statement. You *MUST* use a `for` loop and an `else` statement.

# %%
# I have defined the variable for you.
# RUN THIS CELL FIRST.
# DO NOT CHANGE THIS CELL.
colors = ['red','green','blue']

# %%
# Write your code here to answer the question


#

# %% [markdown]
# What if we want to run a block of code a certain number of times?
#
# We can create a list of numbers using the `range()` function. `range()` can take up to 3 arguments (only 1 is required).
#
# Providing only one argument sets the ending value for the range (starting at 0), e.g., `range(5)` would result in 0,1,2,3,4

# %%
l = range(3)
# Iterate over the list
for x in l:
    print(x)

# %% [markdown]
# Passing two arguments sets the starting and ending values of the range, e.g., `range(1,6)` is 1,2,3,4,5

# %%
l = range(1,6)
# Iterate over the list
for x in l:
    print(x)

# %% [markdown]
# Passing three arguments sets the starting, ending, and increment size values of the range, e.g., `range(1,6,2)` is 1,3,5

# %%
l = range(1,6,2)
# Iterate over the list
for x in l:
    print(x)

# %% [markdown]
# We can even decrement if we want...

# %%
l = range(6,1,-2)
# Iterate over the list
for x in l:
    print(x)

# %% [markdown]
# Nested loops can be used to run a loop within a loop. The inner loop gets run for every iteration of the outer loop.

# %%
l1 = range(3)
l2 = ['blue','yellow','red']
# Iterate over the first list
for x in l1:
    print(x)
    # Iterate over the second list
    for y in l2:
        print(y)
